# %%
#Import all necessary libraries
import pandas as pd

# %% [markdown]
# <h1><u>2.1 Collecting Initial Data</u></h1>

# %%
#importing the csv file using pandas

df = pd.read_excel('Telco_customer_churn.xlsx')  #Make sure you do pip install openpyxl

# %%
#check that all the data were imported correctly. Rows = 7043, Columns = 33

df.shape
# Out:
# (7043, 33)

# %%
#Rationally determine which columns are non-essential

#showing the data-frame in a tabular form
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
#showing the information of the columns

df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7042 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
#Showing count of DISTINCT cities

df['City'].nunique()
# Out:
# 1129

# %% [markdown]
# <h1><u>2.2 Describing Data</u></h1>

# %%
#Showing the data-types again, and Non-Null Counts.

df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7042 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# <h1><u>2.3 Data Exploration</u></h1>

# %%
#Import all necessary libraries in order to visualize

import seaborn as sns
sns.set(color_codes=True) #Setting color_codes = True gives us colors for better visualization

# %%
#Making a copy of our original dataset and replacing the null values within each column to "Missing"

df_null_replaced = df.copy() #Creating a copy of the original data-frame
df_null_replaced.fillna(value = "Missing", inplace = True) #Replacing null values with "Missing"

# %% [markdown]
# <h3>Churn Value</h3>

# %%
plotData = df_null_replaced
columnName = "Churn Value"


plot = sns.countplot(x=columnName, data = plotData)
plot.set(title = columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %% [markdown]
# <h3>Gender</h3>

# %%
plotData = df_null_replaced
columnName = "Gender"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1'), Text(0, 0, '939'), Text(0, 0, '929')]

# %% [markdown]
# <h3>Senior Citizen</h3>

# %%
plotData = df_null_replaced
columnName = "Senior Citizen"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1393'), Text(0, 0, '476')]

# %% [markdown]
# <h3>Partner</h3>

# %%
plotData = df_null_replaced
columnName = "Partner"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1200'), Text(0, 0, '669')]

# %% [markdown]
# <h3>Dependents</h3>

# %%
plotData = df_null_replaced
columnName = "Dependents"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1763'), Text(0, 0, '105'), Text(0, 0, '1')]

# %% [markdown]
# <h3>Tenure Months</h3>

# %%
plotData = df_null_replaced
columnName = "Tenure Months"


plot = sns.histplot(x=columnName, data = plotData, hue = "Churn Value",binwidth = 10, multiple = "stack")
plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name
plot.bar_label(plot.containers[0]) #Shows the Count on the bar for Churn Value = 1
plot.bar_label(plot.containers[1]) #Shows the Count on the bar for Churn Value = 0
# Out:
# [Text(0, 0, '1854'),
#  Text(0, 0, '953'),
#  Text(0, 0, '762'),
#  Text(0, 0, '653'),
#  Text(0, 0, '648'),
#  Text(0, 0, '690'),
#  Text(0, 0, '832'),
#  Text(0, 0, '651')]

# %% [markdown]
# <h3>Phone Service</h3>

# %%
plotData = df_null_replaced
columnName = "Phone Service"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1699'), Text(0, 0, '170')]

# %% [markdown]
# <h3>Multiple Lines</h3>

# %%
plotData = df_null_replaced
columnName = "Multiple Lines"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '849'), Text(0, 0, '850'), Text(0, 0, '170')]

# %% [markdown]
# <h3>Internet Service</h3>

# %%
plotData = df_null_replaced
columnName = "Internet Service"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '459'), Text(0, 0, '1297'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Online Security</h3>

# %%
plotData = df_null_replaced
columnName = "Online Security"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '295'), Text(0, 0, '1461'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Device Protection</h3>

# %%
plotData = df_null_replaced
columnName = "Device Protection"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1211'), Text(0, 0, '545'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Tech Support</h3>

# %%
plotData = df_null_replaced
columnName = "Tech Support"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1446'), Text(0, 0, '310'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Streaming TV</h3>

# %%
plotData = df_null_replaced
columnName = "Streaming TV"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '942'), Text(0, 0, '814'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Streaming Movies</h3>

# %%
plotData = df_null_replaced
columnName = "Streaming Movies"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '938'), Text(0, 0, '818'), Text(0, 0, '113')]

# %% [markdown]
# <h3>Contract</h3>

# %%
plotData = df_null_replaced
columnName = "Contract"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1655'), Text(0, 0, '48'), Text(0, 0, '166')]

# %% [markdown]
# <h3>Paperless Billing</h3>

# %%
plotData = df_null_replaced
columnName = "Paperless Billing"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
# Out:
# [Text(0, 0, '1400'), Text(0, 0, '469')]

# %% [markdown]
# <h3>Payment Method</h3>

# %%
plotData = df_null_replaced
columnName = "Payment Method"


plot = sns.countplot(x=columnName, data = plotData, hue = "Churn Value")
plot.set(title = "Customer Churn in terms of " + columnName) ##Showns The Column Name
plot.bar_label(plot.containers[0]) ##Shows the Count on the bar for Churn Value = 0
plot.bar_label(plot.containers[1]) ##Shows the Count on the bar for Churn Value = 1
plot.tick_params(axis='x',rotation = 90) #Rotating the x labels to 90 degrees for better clarity

# %% [markdown]
# <h3>Monthly Charges</h3>

# %%
plotData = df_null_replaced
columnName = "Monthly Charges"


plot = sns.histplot(x=columnName, data = plotData, hue = "Churn Value", multiple = "stack", bins = 1)
plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name
plot.bar_label(plot.containers[0]) #Shows the Count on the bar for Churn Value = 1
plot.bar_label(plot.containers[1]) #Shows the Count on the bar for Churn Value = 0
# Out:
# [Text(0, 0, '7043')]

# %%
#Checking if there is an outlier. With Min, Max and Mean in the Monthly Charges column

#1.0 Max Value
maxValue = df_null_replaced["Monthly Charges"].max()
print("Max Value: ", maxValue)

#2.0 Min Value
minValue = df_null_replaced["Monthly Charges"].min()
print("Min Value: " , minValue)


#3.0 Mean Value
meanValue = df_null_replaced["Monthly Charges"].mean()
print("Mean Value: ", meanValue )

#4.0 Check that Max Value isn't the only outlier. Sort by descending order
df_monthlyCharges = df_null_replaced.copy() #copying the dataframe in another dataframe variable
df_monthlyCharges = df_monthlyCharges[['Monthly Charges']] #dropping all columns apart from Monthly Charges
df_monthlyCharges['Monthly Charges'] = df['Monthly Charges'].astype('int64') #changing to int64 otherwise it'll display expo numbers
sort_monthlyCharges = df_monthlyCharges.sort_values('Monthly Charges', ascending = False) #sorting in desc order
sort_monthlyCharges #displaying dataframe
# Out:
# Max Value:  1e+18
# Min Value:  18.25
# Mean Value:  141984949595407.66
#           Monthly Charges
# 2098  1000000000000000000
# 1347                  118
# 5417                  118
# 4736                  118
# 5251                  118
# ...                   ...
# 3833                   18
# 4613                   18
# 6758                   18
# 5291                   18
# 3087                   18
#
# [7043 rows x 1 columns]

# %% [markdown]
# <h3>Total Charges</h3>

# %%
plotData = df_null_replaced
columnName = "Total Charges"


plot = sns.histplot(x=columnName, data = plotData, hue = "Churn Value",binwidth = 10, multiple = "stack")
plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name
plot.bar_label(plot.containers[0]) #Shows the Count on the bar for Churn Value = 1
plot.bar_label(plot.containers[1]) #Shows the Count on the bar for Churn Value = 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [124], in <cell line: 5>()
#       1 plotData = df_null_replaced
#       2 columnName = "Total Charges"
# ----> 5 plot = sns.histplot(x=columnName, data = plotData, hue = "Churn Value",binwidth = 10, multiple = "stack")
#       6 plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name
#       7 plot.bar_label(plot.containers[0]) #Shows the Count on the bar for Churn Value = 1
#
# ...

# %%
#Checking how many rows of data in our dataset are there where Total Charges is like " ".

blankCheck_result = df_null_replaced[df_null_replaced["Total Charges"] == " "]  
blankCheck_result
# Out:
#       CustomerID  Count        Country       State            City  Zip Code  \
# 2234  4472-LVYGI      1  United States  California  San Bernardino     92408
# 2438  3115-CZMZD      1  United States  California    Independence     93526
# 2568  5709-LVOEQ      1  United States  California       San Mateo     94401
# 2667  4367-NUYAO      1  United States  California       Cupertino     95014
# 2856  1371-DWPAZ      1  United States  California        Redcrest     95569
# 4331  7644-OMVMY      1  United States  California     Los Angeles     90029
# 4687  3213-VVOLG      1  United States  California        Sun City     92585
# 5104  2520-SGTTA      1  United States  California      Ben Lomond     95005
# 5719  2923-ARZLG      1  United States  California        La Verne     91750
# 6772  4075-WKNIU      1  United States  California            Bell     90201
# 6840  2775-SEFEE      1  United States  California      Wilmington     90744
#
# ...

# %%
#Removing Blank Values from Total Charges in order to display a visualization

totalCharges_withoutBlanks_df = df_null_replaced[df_null_replaced['Total Charges'] != " "] #only include non-blank values of Total Charges to totalCharges_withoutBlanks_df
totalCharges_withoutBlanks_df #Display data to check number of rows (YES = rows now equals to 7032)
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude   Gender  ...  \
# ...

# %% [markdown]
# <h3>Total Charges</h3>

# %%
plotData = totalCharges_withoutBlanks_df
columnName = "Total Charges"

plot = sns.histplot(x=columnName, data = plotData, hue = "Churn Value",binwidth = 10, multiple = "stack")
plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name

#plot.bar_label(plot.containers[0]) #Shows the Count on the bar for Churn Value = 1
#plot.bar_label(plot.containers[1]) #Shows the Count on the bar for Churn Value = 0
# Out:
# [Text(0.5, 1.0, 'Customer Churn in terms of Total Charges')]

# %%
#Show Min.TotalCharges and Max.TotalCharges

minValue = totalCharges_withoutBlanks_df["Total Charges"].min() #min Total Charges
maxValue = totalCharges_withoutBlanks_df["Total Charges"].max() #max Total Charges
print("Min.Total Charges: ", minValue)
print("Max.Total Charges: ", maxValue)
# Out:
# Min.Total Charges:  18.8
# Max.Total Charges:  8684.8

# %% [markdown]
# <h1>2.4 Verifying Data Quality</h1>
# <h3>2.4.1 Missing Values, Null Values and Extreme Values</h3>

# %%
#Gender 
df_null_replaced['Gender'].unique() #To show the unique values (Categories)
# Out:
# array(['Missing', 'Female', 'Male'], dtype=object)

# %%
#Monthly Charges
sort_monthlyCharges
# Out:
#           Monthly Charges
# 2098  1000000000000000000
# 1347                  118
# 5417                  118
# 4736                  118
# 5251                  118
# ...                   ...
# 3833                   18
# 4613                   18
# 6758                   18
# 5291                   18
# 3087                   18
#
# [7043 rows x 1 columns]

# %%
#Total Charges
print('Number of Blank Spaces in Total Charges: ',blankCheck_result['Total Charges'].count())
# Out:
# Number of Blank Spaces in Total Charges:  11

# %% [markdown]
# <h3>2.4.2 Transitive Variables and Re-Coding</h3>

# %%
showingTransitiveDependency_df = df[["Phone Service", "Multiple Lines", "Internet Service", "Online Security", "Online Backup", 
    "Device Protection", "Tech Support"]] #New Data-Frame which online includes above listed columns

showingTransitiveDependency_df[(showingTransitiveDependency_df["Phone Service"] == "No") |
                               (showingTransitiveDependency_df["Internet Service"] == "No")  ] #shows result based on "or" logic
# Out:
#      Phone Service    Multiple Lines Internet Service      Online Security  \
# 6               No  No phone service              DSL                   No
# 7              Yes                No               No  No internet service
# 9               No  No phone service              DSL                   No
# 22             Yes                No               No  No internet service
# 30              No  No phone service              DSL                  Yes
# ...            ...               ...              ...                  ...
# 7032            No  No phone service              DSL                   No
# 7033           Yes                No               No  No internet service
# 7037            No  No phone service              DSL                   No
# 7038           Yes                No               No  No internet service
# 7041            No  No phone service              DSL                  Yes
#
#             Online Backup    Device Protection         Tech Support
# ...

# %% [markdown]
# <h1>3.0 Data Preparation</h1>
# <h3>3.1 Data Selection</h3>

# %%
#Dropping Non-Essential Attributes from our original data-frame "df"

#1 Count
del df["Count"]

#2 Country
del df["Country"]

#3 State
del df["State"]

#4 Zip Code
del df["Zip Code"]

#5 Lat Long
del df["Lat Long"]

#6 Latitude
del df["Latitude"]

#7 Longitude
del df["Longitude"]

#8 Churn Label
del df["Churn Label"]

#9 Churn Score
del df["Churn Score"]

#10 CLTV
del df["CLTV"]

#11 Churn Reason
del df["Churn Reason"]

# %%
#Showing the columns in our data-frame
df.columns
# Out:
# Index(['CustomerID', 'City', 'Gender', 'Senior Citizen', 'Partner',
#        'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges',
#        'Total Charges', 'Churn Value'],
#       dtype='object')

# %% [markdown]
# <h1>3.2 Data Cleaning</h1>
# <h3>3.2.1 Solving Null,Missing and Extreme Values</h3>

# %%
#Gender (Null Value as indicated with count 7042)
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   City               7043 non-null   object
#  2   Gender             7042 non-null   object
#  3   Senior Citizen     7043 non-null   object
#  4   Partner            7043 non-null   object
#  5   Dependents         7043 non-null   object
#  6   Tenure Months      7043 non-null   int64
#  7   Phone Service      7043 non-null   object
#  8   Multiple Lines     7043 non-null   object
#  9   Internet Service   7043 non-null   object
#  10  Online Security    7043 non-null   object
#  11  Online Backup      7043 non-null   object
#  12  Device Protection  7043 non-null   object
#  13  Tech Support       7043 non-null   object
#  14  Streaming TV       7043 non-null   object
#  15  Streaming Movies   7043 non-null   object
# ...

# %%
#Dropping all rows which has NULL Values (NOTE: Gender is the only column with a Null Value)
df = df.dropna() #Dropping all Null Rows 
df.info(verbose = True) #Checking Non-Null Count of Gender
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7042 entries, 1 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7042 non-null   object
#  1   City               7042 non-null   object
#  2   Gender             7042 non-null   object
#  3   Senior Citizen     7042 non-null   object
#  4   Partner            7042 non-null   object
#  5   Dependents         7042 non-null   object
#  6   Tenure Months      7042 non-null   int64
#  7   Phone Service      7042 non-null   object
#  8   Multiple Lines     7042 non-null   object
#  9   Internet Service   7042 non-null   object
#  10  Online Security    7042 non-null   object
#  11  Online Backup      7042 non-null   object
#  12  Device Protection  7042 non-null   object
#  13  Tech Support       7042 non-null   object
#  14  Streaming TV       7042 non-null   object
#  15  Streaming Movies   7042 non-null   object
# ...

# %%
#Monthly Charges [Extreme Value]

# %%
#Dropping all rows which has Monthly Charges values greater than 1000 (NOTE: We know the count is 1)
df = df[df["Monthly Charges"] <= 1000] #df will have all rows which has values <= 1000 [Outlier gets excluded] 
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7041 entries, 1 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7041 non-null   object
#  1   City               7041 non-null   object
#  2   Gender             7041 non-null   object
#  3   Senior Citizen     7041 non-null   object
#  4   Partner            7041 non-null   object
#  5   Dependents         7041 non-null   object
#  6   Tenure Months      7041 non-null   int64
#  7   Phone Service      7041 non-null   object
#  8   Multiple Lines     7041 non-null   object
#  9   Internet Service   7041 non-null   object
#  10  Online Security    7041 non-null   object
#  11  Online Backup      7041 non-null   object
#  12  Device Protection  7041 non-null   object
#  13  Tech Support       7041 non-null   object
#  14  Streaming TV       7041 non-null   object
#  15  Streaming Movies   7041 non-null   object
# ...

# %%
#Showing that the outlier has been removed.
df_removedOutlier = df.copy() #copying the dataframe in another dataframe variable
df_removedOutlier = df_removedOutlier[['Monthly Charges']] #dropping all columns apart from Monthly Charges
df_removedOutlier['Monthly Charges'] = df['Monthly Charges'].astype('int64') #Changing the data-type otherwise it'll display as exp
sort_removedOutlier = df_removedOutlier.sort_values('Monthly Charges', ascending = False)
sort_removedOutlier
# Out:
#       Monthly Charges
# 5417              118
# 5251              118
# 4736              118
# 1347              118
# 6372              118
# ...               ...
# 3087               18
# 3234               18
# 1876               18
# 1710               18
# 1094               18
#
# [7041 rows x 1 columns]

# %% [markdown]
# <h3>3.2.2 Solving Blank Values (Total Charges)</h3>

# %%
#Dropping all the rows and keeping only rows where Total Charges != " "
df = df[df["Total Charges"] != " "] #df will have all rows which hasn't got values " " 
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7030 entries, 1 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7030 non-null   object
#  1   City               7030 non-null   object
#  2   Gender             7030 non-null   object
#  3   Senior Citizen     7030 non-null   object
#  4   Partner            7030 non-null   object
#  5   Dependents         7030 non-null   object
#  6   Tenure Months      7030 non-null   int64
#  7   Phone Service      7030 non-null   object
#  8   Multiple Lines     7030 non-null   object
#  9   Internet Service   7030 non-null   object
#  10  Online Security    7030 non-null   object
#  11  Online Backup      7030 non-null   object
#  12  Device Protection  7030 non-null   object
#  13  Tech Support       7030 non-null   object
#  14  Streaming TV       7030 non-null   object
#  15  Streaming Movies   7030 non-null   object
# ...

# %%
#Check how many rows are there with blank (" ") values in Total Charges
df[df['Total Charges'] == " "]
# Out:
# Empty DataFrame
# Columns: [CustomerID, City, Gender, Senior Citizen, Partner, Dependents, Tenure Months, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn Value]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <h3>3.2.3 Solving Transitive Dependency Variables and Re-encoding</h3>

# %% [markdown]
# <h4>3.2.3A[1] Re-encoding of Multiple Lines Attribute</h4>

# %%
#Multiple Lines - Our goal is to re-encode all the values of "No phone service" in the Multiple Lines field to "No"

df[df["Multiple Lines"] == "No phone service"]  #Check to see count

df["Multiple Lines"] = df["Multiple Lines"].replace(["No phone service"],"No")  #Re-encoding "No phone service" to "No"

df[df["Multiple Lines"] == "No phone service"] #Checking to see count of "No phone service" [Should give 0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, City, Gender, Senior Citizen, Partner, Dependents, Tenure Months, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn Value]
# Index: []
#
# [0 rows x 22 columns]

# %%
df["Multiple Lines"].unique() #To show the unique values in Multiple Lines (Categories: Yes || No)
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# <h4>3.2.3A[2] Re-encoding of "No internet Service" to "No" in Online Security, Online Backup, Device Protection, Tech Support, Streaming TV and Streaming Movies</h4>

# %%
#Our goal is to convert "No internet Service" values to "No" in the fields mentioned. Value of "No internet Service" occurs when
#there is a value of "No" in the Internet Service columns which means TRANSITIVE DEPENDENCY

df[df["Internet Service"] == "No"]  #Check to see the count
# Out:
#       CustomerID                City  Gender Senior Citizen Partner  \
# 7     1066-JKSGK         Los Angeles    Male             No      No
# 22    0278-YXOOG           Inglewood    Male             No      No
# 65    6323-AYBRX             Ontario    Male             No      No
# 99    4895-TMWIR        Indian Wells    Male            Yes     Yes
# 103   4800-VHZKI              Niland  Female             No      No
# ...          ...                 ...     ...            ...     ...
# 7023  4807-IZYOZ  North Palm Springs  Female             No      No
# 7024  9710-NJERN         Palm Desert  Female             No      No
# 7025  9837-FWLCH        Palm Springs    Male             No     Yes
# 7033  0871-OPBXW    Twentynine Palms  Female             No      No
# 7038  2569-WGERO             Landers  Female             No      No
#
#      Dependents  Tenure Months Phone Service Multiple Lines Internet Service  \
# ...

# %%
df[df["Streaming Movies"] == "No internet service"] #Check to see count of "No internet service" in Streaming Movies column.
# Out:
#       CustomerID                City  Gender Senior Citizen Partner  \
# 7     1066-JKSGK         Los Angeles    Male             No      No
# 22    0278-YXOOG           Inglewood    Male             No      No
# 65    6323-AYBRX             Ontario    Male             No      No
# 99    4895-TMWIR        Indian Wells    Male            Yes     Yes
# 103   4800-VHZKI              Niland  Female             No      No
# ...          ...                 ...     ...            ...     ...
# 7023  4807-IZYOZ  North Palm Springs  Female             No      No
# 7024  9710-NJERN         Palm Desert  Female             No      No
# 7025  9837-FWLCH        Palm Springs    Male             No     Yes
# 7033  0871-OPBXW    Twentynine Palms  Female             No      No
# 7038  2569-WGERO             Landers  Female             No      No
#
#      Dependents  Tenure Months Phone Service Multiple Lines Internet Service  \
# ...

# %%
#Replacing "No internet service" with "No" in the entire data-frame. We are 100% certain that the value "No internet service"
#are unique to transitively dependent columns.

df = df.replace(["No internet service"], "No") #Replacing all "No internet serive" to "No"
df[df["Streaming Movies"] == "No internet service"] #Validate by checking rows which has "No internet service" in Streaming Movies
# Out:
# Empty DataFrame
# Columns: [CustomerID, City, Gender, Senior Citizen, Partner, Dependents, Tenure Months, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn Value]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <h3>3.3 Deriving A New Feature</h3>

# %%
#Deriving a new column called onlineChannel.Mailed check will have 0, others will have 1.
df["onlineChannel"] = [0 if i == "Mailed check" else 1
                            for i in df["Payment Method"]]
df
# Out:
#       CustomerID          City  Gender Senior Citizen Partner Dependents  \
# 1     9237-HQITU   Los Angeles  Female             No      No        Yes
# 2     9305-CDSKC   Los Angeles  Female             No      No        Yes
# 3     7892-POOKP   Los Angeles  Female             No     Yes        Yes
# 4     0280-XJGEX   Los Angeles    Male             No      No        Yes
# 5     4190-MFLUW   Los Angeles  Female             No     Yes         No
# ...          ...           ...     ...            ...     ...        ...
# 7038  2569-WGERO       Landers  Female             No      No         No
# 7039  6840-RESVB      Adelanto    Male             No     Yes        Yes
# 7040  2234-XADUH         Amboy  Female             No     Yes        Yes
# 7041  4801-JZAZL  Angelus Oaks  Female             No     Yes        Yes
# 7042  3186-AJIEK  Apple Valley    Male             No      No         No
#
#       Tenure Months Phone Service Multiple Lines Internet Service  ...  \
# ...

# %% [markdown]
# <h3>3.4 Data Integration</h3>

# %%
#Integrating dataset which contains Region into our data-frame.

#Step 1: Importing the Region dataset

df_Region = pd.read_excel('TelcoCustomerWithRegion.xlsx') #import
df_Region #Tabular View
# Out:
#       CustomerID                       Region
# 0     8844-TONUD  Northern San Joaquin Valley
# 1     1455-UGQVH  Northern San Joaquin Valley
# 2     9249-FXSCK  Northern San Joaquin Valley
# 3     1017-FBQMM  Northern San Joaquin Valley
# 4     1635-FJFCC  Southern San Joaquin Valley
# ...          ...                          ...
# 7038  7750-EYXWZ                Inland Empire
# 7039  3540-RZJYU                Central Coast
# 7040  5469-NUJUR                Central Coast
# 7041  1038-RQOST                Central Coast
# 7042  6308-CQRBU                Central Coast
#
# [7043 rows x 2 columns]

# %%
#Step 2: Merging on Inner Join

df = pd.merge(df, df_Region, on="CustomerID", how = "inner") #Inner Join merge
df #Showing data-frame to validate
# Out:
#       CustomerID          City  Gender Senior Citizen Partner Dependents  \
# 0     9237-HQITU   Los Angeles  Female             No      No        Yes
# 1     9305-CDSKC   Los Angeles  Female             No      No        Yes
# 2     7892-POOKP   Los Angeles  Female             No     Yes        Yes
# 3     0280-XJGEX   Los Angeles    Male             No      No        Yes
# 4     4190-MFLUW   Los Angeles  Female             No     Yes         No
# ...          ...           ...     ...            ...     ...        ...
# 7025  2569-WGERO       Landers  Female             No      No         No
# 7026  6840-RESVB      Adelanto    Male             No     Yes        Yes
# 7027  2234-XADUH         Amboy  Female             No     Yes        Yes
# 7028  4801-JZAZL  Angelus Oaks  Female             No     Yes        Yes
# 7029  3186-AJIEK  Apple Valley    Male             No      No         No
#
#       Tenure Months Phone Service Multiple Lines Internet Service  ...  \
# ...

# %% [markdown]
# <h3>3.5 Formatting Data</h3>
# <h4>3.5.1 Audit Check - Removing Illogical Dependents Category</h4>

# %%
df["Dependents"].unique() #To show the unique values in Dependents (Categories: Yes || No || x). "x" here is illogical
# Out:
# array(['Yes', 'No', 'x'], dtype=object)

# %%
#Remove row which has "x" as a value (category) in Dependents columns
df = df[df["Dependents"] != "x"] #df will have all rows which has values not equal to "x"

df["Dependents"].unique() #Should now show unique values of ("Yes" || "No")
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# <h4>3.5.2 Removing Non-Essential Attributes</h4>

# %%
#Checking our data-frame columns
df.columns
# Out:
# Index(['CustomerID', 'City', 'Gender', 'Senior Citizen', 'Partner',
#        'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges',
#        'Total Charges', 'Churn Value', 'onlineChannel', 'Region'],
#       dtype='object')

# %%
#Deleting the CustomerID column from our data-frame
del df["CustomerID"]

df.columns #Checking our data-frame columns now
# Out:
# Index(['City', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Value',
#        'onlineChannel', 'Region'],
#       dtype='object')

# %% [markdown]
# <h4>3.5.3 Assessment of Measurement Types/Data Types

# %%
df.info(verbose = True) #Showing the data-types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7029 entries, 0 to 7029
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7029 non-null   object
#  1   Gender             7029 non-null   object
#  2   Senior Citizen     7029 non-null   object
#  3   Partner            7029 non-null   object
#  4   Dependents         7029 non-null   object
#  5   Tenure Months      7029 non-null   int64
#  6   Phone Service      7029 non-null   object
#  7   Multiple Lines     7029 non-null   object
#  8   Internet Service   7029 non-null   object
#  9   Online Security    7029 non-null   object
#  10  Online Backup      7029 non-null   object
#  11  Device Protection  7029 non-null   object
#  12  Tech Support       7029 non-null   object
#  13  Streaming TV       7029 non-null   object
#  14  Streaming Movies   7029 non-null   object
#  15  Contract           7029 non-null   object
# ...

# %% [markdown]
# <h1>4.0 Data Transformation</h1>
# <h3>4.1 Data Reduction</h3>

# %%
#Show Churn Count.
df["Churn Value"].value_counts()
# Out:
# 0    5162
# 1    1867
# Name: Churn Value, dtype: int64

# %%
#Step 0: Copy the "df" dataframes into two data-frames

df_majorityClass = df.copy()
df_minorityClass = df.copy()

#Step 1: Separate the dataframes based on Churn Value
df_majorityClass = df_majorityClass[df_majorityClass["Churn Value"] == 0] #Has rows where Churn Value = 0
df_minorityClass = df_minorityClass[df_minorityClass["Churn Value"] == 1] #Has rows where Churn Value = 1

# %%
print("df_majorityClass Churn Value Count: ", df_majorityClass['Churn Value'].value_counts()) #Should only show value count of 0
print("df_minorityClass Churn Value Count: ", df_minorityClass['Churn Value'].value_counts()) #Should only show value count of 1
# Out:
# df_majorityClass Churn Value Count:  0    5162
# Name: Churn Value, dtype: int64
# df_minorityClass Churn Value Count:  1    1867
# Name: Churn Value, dtype: int64

# %%
df_majorityClass
# Out:
#               City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 1868   Los Angeles  Female             No     Yes         No              1
# 1869   Los Angeles    Male             No      No         No             34
# 1870   Los Angeles    Male             No      No         No             45
# 1871   Los Angeles    Male             No      No        Yes             22
# 1872   Los Angeles  Female             No      No         No             10
# ...            ...     ...            ...     ...        ...            ...
# 7025       Landers  Female             No      No         No             72
# 7026      Adelanto    Male             No     Yes        Yes             24
# 7027         Amboy  Female             No     Yes        Yes             72
# 7028  Angelus Oaks  Female             No     Yes        Yes             11
# 7029  Apple Valley    Male             No      No         No             66
#
# ...

# %%
#Step 2: Re-Indexing df_majorityClass for upper and lower random bounds
df_majorityClass = df_majorityClass.reset_index(drop=True) #drop=True prevents reset_index from creating column with old index
df_majorityClass
# Out:
#               City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 0      Los Angeles  Female             No     Yes         No              1
# 1      Los Angeles    Male             No      No         No             34
# 2      Los Angeles    Male             No      No         No             45
# 3      Los Angeles    Male             No      No        Yes             22
# 4      Los Angeles  Female             No      No         No             10
# ...            ...     ...            ...     ...        ...            ...
# 5157       Landers  Female             No      No         No             72
# 5158      Adelanto    Male             No     Yes        Yes             24
# 5159         Amboy  Female             No     Yes        Yes             72
# 5160  Angelus Oaks  Female             No     Yes        Yes             11
# 5161  Apple Valley    Male             No      No         No             66
#
# ...

# %%
#Step 3: Shuffling rows within df_majorityClass
df_majorityClass = df_majorityClass.sample(frac=1) #frac specifies the fraction of rows to return in random sample,so frac=1 means to return all in random order

df_majorityClass
# Out:
#                   City  Gender Senior Citizen Partner Dependents  \
# 3623          Chilcoot    Male             No     Yes         No
# 399   Capistrano Beach  Female             No     Yes         No
# 1061        Sacramento  Female            Yes      No         No
# 3101     San Francisco    Male             No     Yes         No
# 2801     Moreno Valley    Male             No     Yes         No
# ...                ...     ...            ...     ...        ...
# 821           San Jose  Female             No     Yes        Yes
# 1436            Guatay    Male             No     Yes         No
# 5116         San Diego    Male             No      No        Yes
# 4078      Garden Grove    Male             No     Yes         No
# 2110    Mi Wuk Village    Male            Yes      No         No
#
#       Tenure Months Phone Service Multiple Lines Internet Service  \
# 3623             70            No             No              DSL
# ...

# %%
#Step 4: Deleting rows randomly (63.83%). Should have around 1867 count in df_majorityClass

df_majorityClass = df_majorityClass.drop(df_majorityClass.sample(frac=0.6383).index) #dropping 63.83% of data
df_majorityClass
# Out:
#                 City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 3101   San Francisco    Male             No     Yes         No             72
# 2801   Moreno Valley    Male             No     Yes         No             72
# 930      Guerneville    Male             No     Yes        Yes             62
# 1418     San Gabriel    Male             No     Yes        Yes              1
# 3087        Pacifica  Female             No     Yes        Yes             70
# ...              ...     ...            ...     ...        ...            ...
# 821         San Jose  Female             No     Yes        Yes             48
# 1436          Guatay    Male             No     Yes         No             14
# 5116       San Diego    Male             No      No        Yes              1
# 4078    Garden Grove    Male             No     Yes         No             70
# 2110  Mi Wuk Village    Male            Yes      No         No             67
#
# ...

# %%
#Step 5: Merging the df_majorityClass and df_minorityClass dataframes
merged_df = pd.concat([df_majorityClass, df_minorityClass]) #Merging Data-frames
df = merged_df #Re-assigning "df" data-frame
df #display df dataframe
# Out:
#                City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 3101  San Francisco    Male             No     Yes         No             72
# 2801  Moreno Valley    Male             No     Yes         No             72
# 930     Guerneville    Male             No     Yes        Yes             62
# 1418    San Gabriel    Male             No     Yes        Yes              1
# 3087       Pacifica  Female             No     Yes        Yes             70
# ...             ...     ...            ...     ...        ...            ...
# 1863   Palm Springs    Male             No      No         No             12
# 1864         Seeley  Female             No      No         No              9
# 1865          Vidal    Male            Yes      No         No              1
# 1866    White Water  Female             No      No         No             67
# 1867   Apple Valley    Male            Yes     Yes         No              4
#
# ...

# %% [markdown]
# <h3>4.2 Data Projection</h3>

# %%
#We are looking at to derive a new column called "LogTotalCharges" which is calculated based upon Log(Total Charges)

#Step 1: Import module
import numpy as np

#Step 2: Create the column
df["LogTotalCharges"] = np.log(df["Total Charges"])

#Step 4: Reset indexes
df = df.reset_index(drop=True)

#Step 5: Display dataframe
df
# Out:
#                City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 0     San Francisco    Male             No     Yes         No             72
# 1     Moreno Valley    Male             No     Yes         No             72
# 2       Guerneville    Male             No     Yes        Yes             62
# 3       San Gabriel    Male             No     Yes        Yes              1
# 4          Pacifica  Female             No     Yes        Yes             70
# ...             ...     ...            ...     ...        ...            ...
# 3729   Palm Springs    Male             No      No         No             12
# 3730         Seeley  Female             No      No         No              9
# 3731          Vidal    Male            Yes      No         No              1
# 3732    White Water  Female             No      No         No             67
# 3733   Apple Valley    Male            Yes     Yes         No              4
#
# ...

# %%
#Visualizing "LogTotalCharges"
plotData = df
columnName = "LogTotalCharges"


plot = sns.histplot(x=columnName, data = plotData,hue = "Churn Value",bins = 50, multiple = "stack")
plot.set(title = "Customer Churn in terms of " + columnName) #Shows the Column Name
# Out:
# [Text(0.5, 1.0, 'Customer Churn in terms of LogTotalCharges')]

# %%
#Checking columns
df.columns
# Out:
# Index(['City', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Value',
#        'onlineChannel', 'Region', 'LogTotalCharges'],
#       dtype='object')

# %%
#remove "TotalCharges" column and "City" columns
df = df.drop(['Total Charges'],axis=1)
df = df.drop(['City'],axis=1)

#check if column was dropped
df.columns
# Out:
# Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Churn Value', 'onlineChannel',
#        'Region', 'LogTotalCharges'],
#       dtype='object')

# %%
# Creating Dummy Variables and over-writing our dataframe (df)
df = pd.get_dummies(df)

# Show the dataframe
df.head()
# Out:
#    Tenure Months  Monthly Charges  Churn Value  onlineChannel  \
# 0             72           108.20            0              1
# 1             72            88.70            0              1
# 2             62           115.55            0              1
# 3              1            81.05            0              1
# 4             70            24.05            0              0
#
#    LogTotalCharges  Gender_Female  Gender_Male  Senior Citizen_No  \
# 0         8.967071              0            1                  1
# 1         8.748575              0            1                  1
# 2         8.876133              0            1                  1
# 3         4.395066              0            1                  1
# 4         7.475764              1            0                  1
#
#    Senior Citizen_Yes  Partner_No  ...  Region_Central Coast  \
# 0                   0           0  ...                     0
# 1                   0           0  ...                     0
# ...

# %%
df.columns
# Out:
# Index(['Tenure Months', 'Monthly Charges', 'Churn Value', 'onlineChannel',
#        'LogTotalCharges', 'Gender_Female', 'Gender_Male', 'Senior Citizen_No',
#        'Senior Citizen_Yes', 'Partner_No', 'Partner_Yes', 'Dependents_No',
#        'Dependents_Yes', 'Phone Service_No', 'Phone Service_Yes',
#        'Multiple Lines_No', 'Multiple Lines_Yes', 'Internet Service_DSL',
#        'Internet Service_Fiber optic', 'Internet Service_No',
#        'Online Security_No', 'Online Security_Yes', 'Online Backup_No',
#        'Online Backup_Yes', 'Device Protection_No', 'Device Protection_Yes',
#        'Tech Support_No', 'Tech Support_Yes', 'Streaming TV_No',
#        'Streaming TV_Yes', 'Streaming Movies_No', 'Streaming Movies_Yes',
#        'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
#        'Paperless Billing_No', 'Paperless Billing_Yes',
#        'Payment Method_Bank transfer (automatic)',
#        'Payment Method_Credit card (automatic)',
# ...

# %%
# Deleting "Dummy Variables Excluded"

#Gender_Male
del df['Gender_Male']

#SeniorCitizen_No
del df['Senior Citizen_No']

#Partner_No
del df['Partner_No']

#Dependents_No
del df['Dependents_No']

#PhoneService_No
del df['Phone Service_No']

#MultipleLines_No
del df['Multiple Lines_No']

#InternetService_No
del df['Internet Service_No']

#OnlineSecurity_No
del df['Online Security_No']

#OnlineBackup_No
del df['Online Backup_No']

#DeviceProtection_No
del df['Device Protection_No']

#TechSupport_No
del df['Tech Support_No']

#StreamingTV_No
del df['Streaming TV_No']

#StreamingMovies_No
del df['Streaming Movies_No']

#Contract_Two year
del df['Contract_Two year']

#PaperlessBilling_No
del df['Paperless Billing_No']

#PaymentMethod_Mailed check
del df['Payment Method_Mailed check']

#Region_Superior California
del df['Region_Superior California']

# %%
#Check to validate that the columns were successfully deleted
df.columns
# Out:
# Index(['Tenure Months', 'Monthly Charges', 'Churn Value', 'onlineChannel',
#        'LogTotalCharges', 'Gender_Female', 'Senior Citizen_Yes', 'Partner_Yes',
#        'Dependents_Yes', 'Phone Service_Yes', 'Multiple Lines_Yes',
#        'Internet Service_DSL', 'Internet Service_Fiber optic',
#        'Online Security_Yes', 'Online Backup_Yes', 'Device Protection_Yes',
#        'Tech Support_Yes', 'Streaming TV_Yes', 'Streaming Movies_Yes',
#        'Contract_Month-to-month', 'Contract_One year', 'Paperless Billing_Yes',
#        'Payment Method_Bank transfer (automatic)',
#        'Payment Method_Credit card (automatic)',
#        'Payment Method_Electronic check', 'Region_Central Coast',
#        'Region_Inland Empire', 'Region_Los Angeles County',
#        'Region_North Coast', 'Region_Northern San Joaquin Valley',
#        'Region_Orange County', 'Region_San Diego - Imperial',
#        'Region_San Franciso Bay Area', 'Region_Southern San Joaquin Valley'],
#       dtype='object')

# %% [markdown]
# <h3>Data-Mining Objective: 1</h3>

# %%
#Data-Mining Objective: 1

#Step 1: Assigning our x (independent variables) and y (dependent variable)
X = df.loc[:, df.columns != 'Churn Value']     #X is all columns apart from the "ChurnValue" columns
y = df['Churn Value']

#Step 2: Importing the statsmodels library
import statsmodels.api as sn
import statsmodels.discrete.discrete_model as sm

#Step 3: Adding Constants to X_cons
X_cons = sn.add_constant(X) #adding constant to X_cons (REMEMBER: This was 0 by default)
X_cons.head() #checking our dataframe of x variables
# Out:
#    const  Tenure Months  Monthly Charges  onlineChannel  LogTotalCharges  \
# 0    1.0             72           108.20              1         8.967071
# 1    1.0             72            88.70              1         8.748575
# 2    1.0             62           115.55              1         8.876133
# 3    1.0              1            81.05              1         4.395066
# 4    1.0             70            24.05              0         7.475764
#
#    Gender_Female  Senior Citizen_Yes  Partner_Yes  Dependents_Yes  \
# 0              0                   0            1               0
# 1              0                   0            1               0
# 2              0                   0            1               1
# 3              0                   0            1               1
# 4              1                   0            1               1
#
#    Phone Service_Yes  ...  Payment Method_Electronic check  \
# 0                  1  ...                                1
# ...

# %%
#Step 4: Actually running the Logistic Regression Model
# We have already imported the model in Step 2 from the library as "sm"

logit = sm.Logit(y, X_cons).fit() #building our model
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453950
#          Iterations 16

# %%
#Step 5: Get statistical summary
logit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Churn Value   No. Observations:                 3734
# Model:                          Logit   Df Residuals:                     3701
# Method:                           MLE   Df Model:                           32
# Date:                Thu, 13 Oct 2022   Pseudo R-squ.:                  0.3451
# Time:                        14:23:19   Log-Likelihood:                -1695.0
# converged:                       True   LL-Null:                       -2588.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...

# %%
#Step 5: Calculating the odds ratio
    #We know that the odds ratio is Exp(B) where B is the coefficient value

import numpy as np   #importing numpy for exp use

model_odds = pd.DataFrame(np.exp(logit.params), columns = ['Exp(B)'])

print(model_odds)
# Out:
#                                               Exp(B)
# const                                       2.030512
# Tenure Months                               0.995595
# Monthly Charges                             0.922863
# onlineChannel                               1.070634
# LogTotalCharges                             0.562849
# Gender_Female                               0.926347
# Senior Citizen_Yes                          1.053629
# Partner_Yes                                 1.318009
# Dependents_Yes                              0.203157
# Phone Service_Yes                           3.746356
# Multiple Lines_Yes                          2.242312
# Internet Service_DSL                       28.253503
# Internet Service_Fiber optic              630.379921
# Online Security_Yes                         1.235747
# Online Backup_Yes                           1.403481
# Device Protection_Yes                       1.688839
# Tech Support_Yes                            1.213032
# ...

# %% [markdown]
# <h3>Data-Mining Objective: 2</h3>

# %%
#Step 1: importing essential libraries
from sklearn.model_selection import train_test_split       
from sklearn.linear_model import LogisticRegression

# %%
#Step 2: train and test split (80:20)

#2A: Generate the training set. Set random_state to be able to replicate results
train = df.sample(frac = 0.8, random_state = 1)

#2B: Select anything not in the training set and put it in the testing set
test = df.loc[~df.index.isin(train.index)]

#2C: Print the shapes of both sets
print(train.shape)
print(test.shape)
# Out:
# (2987, 34)
# (747, 34)

# %%
#Step 3: 

#3A: Creating our classification object:
clf_LR = LogisticRegression() #cls_lrs stands for classification_logisticRegression

#3B: Getting training and testing columns:
x_train = train.loc[:, train.columns != 'Churn Value']     #X is all train dataset columns apart from the "ChurnValue" columns
y_train = train['Churn Value']                             #Y is ChurnValue
x_test  = test.loc[:, train.columns != 'Churn Value']      #X is all test dataset columns apart from the "ChurnValue" columns
y_test  = test['Churn Value']                              #Y is ChurnValue

#3C: Fitting the model to train:
clf_LR.fit(x_train, y_train)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Step 4: Testing the model

#4A: Checking our model on testing dataset
y_test_prediction = clf_LR.predict(x_test)

#4B: Import
from sklearn.metrics import accuracy_score, confusion_matrix

#4C: Confusion_Matrix Testing Dataset
print("Confusion_Matrix")
print(confusion_matrix(y_test, y_test_prediction))
print()
print()

#4D: Accuracy_Score Testing Dataset
print("Accuracy_Score")
print(accuracy_score(y_test, y_test_prediction))
# Out:
# Confusion_Matrix
# [[280 106]
#  [ 74 287]]
#
#
# Accuracy_Score
# 0.7590361445783133

# %%
#Pattern Search - We want to know the confusion matrix and accuracy score for our training dataset
y_train_prediciton = clf_LR.predict(x_train)

print("Confusion_Matrix")
print(confusion_matrix(y_train, y_train_prediciton))
print()
print()

print("Accuracy_Score")
print (accuracy_score(y_train, y_train_prediciton))
# Out:
# Confusion_Matrix
# [[1122  359]
#  [ 269 1237]]
#
#
# Accuracy_Score
# 0.7897556076330766
